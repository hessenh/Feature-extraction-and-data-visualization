# %%
import numpy as np
import pandas as pd
import math as math
import matplotlib.pyplot as plt
import charts
pd.set_option('html',False)
from os import path
# Out:
# Server running in the folder /home/hessenh/Development/Prosjektoppgave/Notebook/Visualization at 127.0.0.1:33583

# %%
CHEST_X = path.relpath('../data/P03/DATA_WINDOW/Axivity_CHEST_Back_X.csv')
CHEST_Y = path.relpath('../data/P03/DATA_WINDOW/Axivity_CHEST_Back_Y.csv')
CHEST_Z = path.relpath('../data/P03/DATA_WINDOW/Axivity_CHEST_Back_Z.csv')

THIGH_X = path.relpath('../data/P03/DATA_WINDOW/Axivity_THIGH_Left_X.csv')
THIGH_Y = path.relpath('../data/P03/DATA_WINDOW/Axivity_THIGH_Left_Y.csv')
THIGH_Z = path.relpath('../data/P03/DATA_WINDOW/Axivity_THIGH_Left_Z.csv')

LABEL = path.relpath('../data/P03/DATA_WINDOW/Usability_LAB_All_L.csv')

df_chest_x = pd.read_csv(CHEST_X, header=None, sep='\,')
df_chest_y = pd.read_csv(CHEST_Y, header=None, sep='\,')
df_chest_z = pd.read_csv(CHEST_Z, header=None, sep='\,')

df_thigh_x = pd.read_csv(THIGH_X, header=None, sep='\,')
df_thigh_y = pd.read_csv(THIGH_Y, header=None, sep='\,')
df_thigh_z = pd.read_csv(THIGH_Z, header=None, sep='\,')

df_label = pd.read_csv(LABEL, header=None, sep='\ ')
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:648: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
def fourierTransform(slidingWindow):
    #sliding window from time domain to frequency domain
    fft_output = np.fft.fft(slidingWindow)
    magnitude = abs(fft_output)
    frequencies = np.fft.fftfreq(len(slidingWindow))*len(slidingWindow)    #magnitude_only = [math.sqrt(i.real**2 + i.imag**2)/len(fft_output) for i in fft_output]
    #frequencies = [(i*1.0/100)*100 for i in range(100/2+1)]
    #Make plotable array
    plotArray = []
    for i in range(0,len(slidingWindow)/2):
        elements = []
        elements.append(frequencies[i])
        elements.append(magnitude[i])
        plotArray.append(elements)
    
    return fft_output, magnitude, frequencies, plotArray

# %%
df_sensor = df_chest_x

point = 409

options = dict( 
    title=dict(
        text='time domain' + str(df_label.iloc[point].values)),
    chart=dict(zoomType='xy')
)

charts.plot(df_sensor.iloc[point], options=options, show='inline')
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;font-family:sans-serif}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# ...

# %%
fft_output, magnitude, frequencies, plotableArray = fourierTransform(df_sensor.iloc[point])



options = dict(
    title=dict(
        text='frequency domain'),
    chart=dict(zoomType='xy')
)

charts.plot(plotableArray[0:100], options=options, show='inline')
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;font-family:sans-serif}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# ...

# %%
#print fft_output 
#print magnitude #abs(fft_output)
#print frequencies
print np.mean(abs(magnitude))
print len(abs(magnitude))
# Out:
# 7.27665399335
# 1000

# %%
# fft_output consists of complex numbers, A,B... 
# X = A exp(i w1 t) + B exp(i w2 t) + ...
# A complex number can be written as A = r exp(ip) where r = abs(A) and p=angle(A)

#absolute and angle part of fft output
absolute = abs(fft_output)
angle = np.angle(fft_output)

# %%
for i in range(309,600):
    fft_output, magnitude, frequencies, plotableArray = fourierTransform(df_chest_x.iloc[i])
    print np.mean(magnitude)
# Out:
# 1.57345159031
# 1.23620052204
# 1.45592278193
# 1.98029226323
# 2.06174570971
# 2.23357214016
# 2.33986387326
# 2.45569323883
# 1.23500864108
# 1.11085021635
# 1.0731116654
# 1.07972361944
# 1.15831972939
# 1.13944997318
# 1.07271950823
# 1.07389726972
# 1.03969890773
# 1.1092910974
# 1.19072776643
# 1.18665383165
# 1.08063514795
# 1.05190160851
# 1.12904638711
# 1.19535194864
# 1.46490699383
# 1.50229333156
# 1.281451914
# 1.38889577005
# 1.23970076446
# 1.05659179009
# 1.74636261786
# 1.84995350324
# 1.83634024513
# 1.20160589848
# 1.12386406236
# 1.0732187997
# 1.0901642149
# 1.22406093678
# 1.227763313
# 1.11574552902
# 1.09297711555
# 1.06624749889
# 1.04085747056
# 1.05150814089
# 1.2209389917
# 1.24355155496
# 1.20125392931
# 1.21360203506
# 1.16392590128
# 1.11712267707
# 1.0858799637
# 1.05148380784
# 1.08767538452
# 1.40494749828
# 1.57238007327
# 1.44139932621
# 1.33736439059
# 1.44781079835
# 2.34974121677
# 2.72894809958
# 2.50789825746
# 2.67473456783
# 2.01206979043
# ...
