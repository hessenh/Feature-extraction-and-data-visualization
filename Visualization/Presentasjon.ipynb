# %% [markdown]
# <h1> Human Activitiy Recognition</h1>

# %% [markdown]
# <h3>Activities</h3>
# - walking
# - shuffling
# - standing
# - sitting
# - lying
# - transition
# - leaning
# - jumping
# - picking
# - kneeling

# %%
from IPython.display import Image
Image('HARsystem.png')

# %% [markdown]
# <h3>Preprocessing</h3>
# - Divide the signal into X,Y,Z
# - Smooth it with a Gaussian filter

# %% [markdown]
# <h3>Segmenting</h3>
# - Segmented the signal and labels into overlapping windows
# - One and five second

# %% [markdown]
# <h3>Extracting Features</h3>
# - Background research
# - Time and frequency domain

# %%
Image('features.png')

# %%
Image('angle_activity_thigh.png')

# %% [markdown]
# <h3>Feature selection</h3>
# - WEKA
# - Filter and wrapper methods

# %% [markdown]
# <h3>Classification Algorithms</h3>
# - Support Vector Machine (SVM)
# - Neural Network (NN)
# - Random Forest
# - Naive Bayes
# - Decision Tree (J48)

# %% [markdown]
# <h2>Results</h2>

# %% [markdown]
# - Filtering methods selected similar features (same activity split)
# - Mainly from thigh sensor

# %%
Image('DC_angle_thigh.png')

# %% [markdown]
# - Wrapper methods selected combination of features

# %%
Image('mean_chest_z.png')

# %%
Image('max_thigh_x.png')

# %% [markdown]
# <h3>Random Forest</h3>
# - Accuracy: 89.4 %

# %%
Image('conf_1_wrapper_rf.png')

# %% [markdown]
# <h1>Current work</h3>

# %% [markdown]
# - Convolutional Neural Network

# %%
Image('CNN.png')

# %% [markdown]
# - Dynamic Classification Algorithms (HMM - Viterbi)
# - Hierachical Classification System

# %%
Image('classifier_hier.png')
