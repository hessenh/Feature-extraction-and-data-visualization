# %% [markdown]
# <h1>Subject P03</h1>

# %% [markdown]
# <h2> Visualize the raw data </h2>

# %%
import numpy as np
import pandas as pd
pd.set_option('html',False)

from os import path

# %%
from numpy import random
import matplotlib.pyplot as plt
import sys #only needed to determine Python version number

# Enable inline plotting
# %matplotlib inline
#%matplotlib qt
#%pylab qt

CHEST = path.relpath('data/P03/P03_Axivity_CHEST_Back.csv')
THIGH = path.relpath('data/P03/P03_Axivity_THIGH_Left.csv')
LABEL = path.relpath('data/P03/P03_Usability_LAB_All.csv')

df_chest = pd.read_csv(CHEST, header=None, sep='\,')
df_thigh = pd.read_csv(THIGH, header=None, sep='\,')
df_label = pd.read_csv(LABEL, header=None, sep='\ ')
# Out:
#                 0        1         2
# 0        0.056043  1.01060 -0.076371
# 1        0.068261  0.97648 -0.071339
# 2        0.076152  0.98130 -0.061553
# 3        0.069247  0.99905 -0.061553
# 4        0.048230  0.98182 -0.062500
# 5        0.033736  0.98887 -0.065577
# 6        0.031250  1.00150 -0.066406
# 7        0.047033  0.97234 -0.072720
# 8        0.070153  0.99713 -0.083905
# 9        0.077494  1.00060 -0.092487
# 10       0.068182  0.97348 -0.107010
# 11       0.076468  1.01570 -0.092606
# 12       0.061159  0.98272 -0.096630
# 13       0.058594  1.04590 -0.101120
# 14       0.041036  0.97041 -0.098051
# 15       0.046165  0.95028 -0.076350
# 16       0.057647  1.04620 -0.070629
# 17       0.058594  0.89334 -0.132650
# 18       0.054885  1.00520 -0.058831
# 19       0.050939  1.00420 -0.065933
# 20       0.069721  1.00390 -0.081558
# 21       0.054847  1.03870 -0.066565
# 22       0.082031  1.14840 -0.136720
# 23       0.089489  1.04700 -0.135100
# ...

# %% [markdown]
# <h1>Testing new ploting</h1>

# %%
import charts

# %%
start = 100000 #int(len(df_label)* 0.75)
length = 10000
df_chest = df_chest[start:start + length] + 15
df_thigh = df_thigh[start:start + length] + 20
df_label = df_label[start:start + length]

# %%
df_chest_thigh = pd.concat([df_chest, df_thigh, df_label],axis=1,ignore_index=True)

# Resample the data: Only take every 5th data point, to ease the plotting!
df_chest_thigh_resampled = df_chest_thigh.iloc[::10, :]

options = dict(
    height=1000, 
    title=dict(
        text='Chest and thigh'),
    chart=dict(zoomType='xy')
)

# Name for the plot. Saving the plot as START_STOP.svg. 
name = str(start) + "_" + str(length) + ".svg"
charts.plot(df_chest_thigh_resampled, options=options, save=name, show='inline')
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;font-family:sans-serif}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# ...

# %% [markdown]
# <h1>Label explanation</h1>

# %% [markdown]
# <p>1: Walking<p>
# <p>2: Walking with transitions<p>
# <p>3: Shuffeling<p>
# <p>4: Stairs(acc)<p>
# <p>5: Stairs(dec)<p>
# <p>6: Standing<p>
# <p>7: Sitting<p>
# <p>8: Lying<p>
# <p>9: Transition<p>
# <p>10: Leaning<p>
# <p>11: Undefined<p>
# <p>12: Jumping<p>
# <p>13: Dynamic<p>
# <p>14: Static<p>
