# %%
import numpy as np
import pandas as pd
pd.set_option('html',False)

# %%
CHEST_X = '/home/astrid/Development/Prosjektoppgave/Notebook/data/P03_DATA_WINDOW/PO3_CHEST_X.csv'
CHEST_Y = '/home/astrid/Development/Prosjektoppgave/Notebook/data/P03_DATA_WINDOW/PO3_CHEST_Y.csv'
CHEST_Z = '/home/astrid/Development/Prosjektoppgave/Notebook/data/P03_DATA_WINDOW/PO3_CHEST_Z.csv'

THIGH_X = '/home/astrid/Development/Prosjektoppgave/Notebook/data/P03_DATA_WINDOW/PO3_THIGH_X.csv'
THIGH_Y = '/home/astrid/Development/Prosjektoppgave/Notebook/data/P03_DATA_WINDOW/PO3_THIGH_Y.csv'
THIGH_Z = '/home/astrid/Development/Prosjektoppgave/Notebook/data/P03_DATA_WINDOW/PO3_THIGH_Z.csv'

LABEL = '/home/astrid/Development/Prosjektoppgave/Notebook/data/P03_DATA_WINDOW/P03_LABEL_L.csv'

df_chest_x = pd.read_csv(CHEST_X, header=None, sep='\,')
df_chest_y = pd.read_csv(CHEST_Y, header=None, sep='\,')
df_chest_z = pd.read_csv(CHEST_Z, header=None, sep='\,')

df_thigh_x = pd.read_csv(THIGH_X, header=None, sep='\,')
df_thigh_y = pd.read_csv(THIGH_Y, header=None, sep='\,')
df_thigh_z = pd.read_csv(THIGH_Z, header=None, sep='\,')

df_label = pd.read_csv(LABEL, header=None, sep='\ ')

# %%
#bruker numpy fast fourier transform til å transform et sliding window til frequency domain 

df_chest_250 = df_chest_x.iloc[250]
print df_chest_250

df_fourier = np.fft.fft(df_chest_x.iloc[250])
print len(df_fourier)

print df_fourier
# Out:
# 0    -0.038
# 1    -0.038
# 2    -0.038
# 3    -0.032
# 4    -0.032
# 5    -0.038
# 6    -0.038
# 7    -0.032
# 8    -0.038
# 9    -0.038
# 10   -0.041
# 11   -0.032
# 12   -0.038
# 13   -0.038
# 14   -0.038
# 15   -0.038
# 16   -0.038
# 17   -0.041
# 18   -0.038
# 19   -0.038
# 20   -0.038
# 21   -0.038
# 22   -0.032
# 23   -0.041
# 24   -0.032
# 25   -0.032
# 26   -0.038
# 27   -0.038
# 28   -0.032
# 29   -0.038
#       ...
# 70   -0.032
# 71   -0.038
# 72   -0.041
# 73   -0.032
# 74   -0.032
# 75   -0.032
# 76   -0.032
# 77   -0.032
# 78   -0.032
# 79   -0.032
# 80   -0.032
# 81   -0.038
# 82   -0.032
# 83   -0.038
# 84   -0.038
# 85   -0.041
# 86   -0.038
# 87   -0.038
# 88   -0.038
# 89   -0.038
# 90   -0.032
# 91   -0.038
# 92   -0.038
# 93   -0.038
# 94   -0.038
# 95   -0.032
# 96   -0.038
# 97   -0.038
# 98   -0.038
# 99   -0.038
# Name: 250, dtype: float64
# 100
# [ -3.63200000e+00 +0.00000000e+00j  -1.20206203e-02 +3.32314913e-02j
#   -4.18754085e-02 +5.56907864e-03j   2.32040093e-02 -2.43103655e-02j
#    3.87205779e-02 -4.21010416e-02j   1.04912217e-02 +3.01039859e-02j
#   -3.97540965e-02 -9.20946883e-03j  -2.93701129e-02 -1.28690460e-02j
#   -2.08004362e-03 +1.35238460e-02j   2.04451828e-02 -6.52047331e-02j
#   -9.13525492e-03 +2.24090846e-02j  -2.48357036e-02 +8.52780094e-03j
#   -3.70873231e-03 -2.84273507e-02j  -1.93025711e-02 +3.36588566e-02j
#   -1.67635985e-02 -7.75492686e-03j  -2.42242723e-02 -1.42844728e-02j
#    2.41427721e-02 -1.46530997e-02j  -1.20154268e-02 +2.02312270e-02j
#   -1.32210387e-03 -3.42276153e-02j   5.62978241e-03 +4.94237341e-03j
#    1.59270510e-02 +6.37988106e-03j  -2.43949885e-02 +1.71739986e-02j
#    8.93658985e-03 -1.73896532e-02j   1.66578473e-03 +3.95408711e-02j
